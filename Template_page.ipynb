# %%
# "Title"
> "Awesome summary"

- toc: false # table of content

- branch: master # The branch field is used to optionally render a link your notebook to Colab and GitHub in your blog post post.
# It'll default to master if you don't specify it in the notebook.

- badges: true
# If you do not want to show Colab / GitHub badges on your blog post
# (perhaps because your repo is private and the links would be broken) set badges to false. This defaults to true
# By default, when you omit this parameter from your front matter, or you set badges:
# true, all three badges (GitHub, Binder, Colab) will appear by default.

# If only want to hide a badge on an individual post, you can set the front matter hide_{github,colab,binder}_badge: true.
# For example, if you wanted to hide the Binder badge for an individual notebook
# but you want the other badges to show up, you can set this in your front matter:
#- badges: true
#- hide_binder_badge: true
# You can read more: https://mybinder.readthedocs.io/en/latest/introduction.html

- badges: true
- hide_binder_badge: true

- comments: true # Make sure the repo is public, Make sure the utterances app is installed on the repo
- categories: [fastpages, jupyter] # Add tags to table of content
# You can toggle the display of tags on/off by setting show_tags to true or false in _config.yml:
# Set this to true to display tags on each post
# show_tags: true

- image: images/some_folder/your_image.png
- hide: false
- search_exclude: true
- metadata_key1: metadata_value1
- metadata_key2: metadata_value2

# %% [markdown]
# Add the following to the blogs template wherever you want the comments to appear.
# ```
# <script src="https://utteranc.es/client.js"
#         repo="[ENTER REPO HERE]"
#         issue-term="pathname"
#         label="Utterances_Autogenerated"
#         theme="github-light"
#         crossorigin="anonymous"
#         async>
# </script>
# ```
